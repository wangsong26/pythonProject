# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series(np.random.randn(5),index=list('abcde'))
s
# Out:
# a   -0.152702
# b    0.477214
# c   -1.664785
# d   -0.171916
# e   -1.132054
# dtype: float64

# %%
s=pd.Series(np.random.randn(5))
s
# Out:
# 0   -0.241826
# 1    1.402665
# 2   -0.799659
# 3   -0.239760
# 4    0.112521
# dtype: float64

# %%
s[:3]
# Out:
# 0   -0.241826
# 1    1.402665
# 2   -0.799659
# dtype: float64

# %%
s[[4,3,2]]
# Out:
# 4    0.112521
# 3   -0.239760
# 2   -0.799659
# dtype: float64

# %%
s=pd.Series(np.random.randn(5),index=list('abcde'))
s
# Out:
# a   -0.977524
# b    0.511936
# c   -1.402287
# d   -0.908608
# e   -0.250532
# dtype: float64

# %%
'a' in s
# Out:
# True

# %%
import pandas as pd
rng=pd.date_range('1/1/2020',periods=100,freq='S')
rng
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 00:00:01',
#                '2020-01-01 00:00:02', '2020-01-01 00:00:03',
#                '2020-01-01 00:00:04', '2020-01-01 00:00:05',
#                '2020-01-01 00:00:06', '2020-01-01 00:00:07',
#                '2020-01-01 00:00:08', '2020-01-01 00:00:09',
#                '2020-01-01 00:00:10', '2020-01-01 00:00:11',
#                '2020-01-01 00:00:12', '2020-01-01 00:00:13',
#                '2020-01-01 00:00:14', '2020-01-01 00:00:15',
#                '2020-01-01 00:00:16', '2020-01-01 00:00:17',
#                '2020-01-01 00:00:18', '2020-01-01 00:00:19',
#                '2020-01-01 00:00:20', '2020-01-01 00:00:21',
#                '2020-01-01 00:00:22', '2020-01-01 00:00:23',
#                '2020-01-01 00:00:24', '2020-01-01 00:00:25',
#                '2020-01-01 00:00:26', '2020-01-01 00:00:27',
#                '2020-01-01 00:00:28', '2020-01-01 00:00:29',
# ...

# %%
ts=pd.Series(np.random.randint(0,500,len(rng)), index=rng)
ts
# Out:
# 2020-01-01 00:00:00    400
# 2020-01-01 00:00:01     56
# 2020-01-01 00:00:02    458
# 2020-01-01 00:00:03     52
# 2020-01-01 00:00:04     29
#                       ...
# 2020-01-01 00:01:35    177
# 2020-01-01 00:01:36    131
# 2020-01-01 00:01:37    220
# 2020-01-01 00:01:38     30
# 2020-01-01 00:01:39    293
# Freq: S, Length: 100, dtype: int64

# %%
ts.resample('1Min').sum()
# Out:
# 2020-01-01 00:00:00    13504
# 2020-01-01 00:01:00    11360
# Freq: T, dtype: int64

# %%
s1=pd.Series([1.,2.,3.],index=list('abc'))
s2=pd.Series([1.,2.,3.,4.],index=list('abcd'))
d={'one':s1,
  'two':s2}

# %%
s1
# Out:
# a    1.0
# b    2.0
# c    3.0
# dtype: float64

# %%
s2
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %%
pd.DataFrame(d,index=['d','b','a'],columns=['two','yyy'])
# Out:
#    two  yyy
# d  4.0  NaN
# b  2.0  NaN
# a  1.0  NaN

# %%
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
df['three']=df['one']*df['two']
df
# Out:
#    one  two  three
# a  1.0  1.0    1.0
# b  2.0  2.0    4.0
# c  3.0  3.0    9.0
# d  NaN  4.0    NaN

# %%
# Out:
#    one  two  three
# a  1.0  1.0    1.0
# b  2.0  2.0    4.0
# c  3.0  3.0    9.0
# d  NaN  4.0    NaN

# %%
osstat_csv=pd.read_csv('os_stats.csv')
osstat_csv
# Out:
#                                               FILE DB_NAME       DB_ID  \
# 0   db03bs1-20200217_080033-00036413-00036414.html  DB03BS  2633216536
# 1   db03bs1-20200217_080033-00036413-00036414.html  DB03BS  2633216536
# 2   db03bs1-20200217_090003-00036414-00036415.html  DB03BS  2633216536
# 3   db03bs1-20200217_090003-00036414-00036415.html  DB03BS  2633216536
# 4   db03bs1-20200217_100011-00036415-00036416.html  DB03BS  2633216536
# ..                                             ...     ...         ...
# 75  db03bs2-20200218_010000-00036430-00036431.html  DB03BS  2633216536
# 76  db03bs2-20200218_020007-00036431-00036432.html  DB03BS  2633216536
# 77  db03bs2-20200218_020007-00036431-00036432.html  DB03BS  2633216536
# 78  db03bs2-20200218_030002-00036432-00036433.html  DB03BS  2633216536
# 79  db03bs2-20200218_030002-00036432-00036433.html  DB03BS  2633216536
#
#    INSTANCE  INST_NUM     STARTUP_TIME     RELEASE  RAC  \
# 0   db03bs1         1  30-Apr-19 07:04  12.1.0.2.0  YES
# ...

# %%
osstat_csv.head()
# Out:
#                                              FILE DB_NAME       DB_ID  \
# 0  db03bs1-20200217_080033-00036413-00036414.html  DB03BS  2633216536
# 1  db03bs1-20200217_080033-00036413-00036414.html  DB03BS  2633216536
# 2  db03bs1-20200217_090003-00036414-00036415.html  DB03BS  2633216536
# 3  db03bs1-20200217_090003-00036414-00036415.html  DB03BS  2633216536
# 4  db03bs1-20200217_100011-00036415-00036416.html  DB03BS  2633216536
#
#   INSTANCE  INST_NUM     STARTUP_TIME     RELEASE  RAC              HOST_NAME  \
# 0  db03bs1         1  30-Apr-19 07:04  12.1.0.2.0  YES  eoeo03v1.ekiban.local
# 1  db03bs1         1  30-Apr-19 07:04  12.1.0.2.0  YES  eoeo03v1.ekiban.local
# 2  db03bs1         1  30-Apr-19 07:04  12.1.0.2.0  YES  eoeo03v1.ekiban.local
# 3  db03bs1         1  30-Apr-19 07:04  12.1.0.2.0  YES  eoeo03v1.ekiban.local
# 4  db03bs1         1  30-Apr-19 07:04  12.1.0.2.0  YES  eoeo03v1.ekiban.local
#
# ...

# %%
osstat_csv.assign(user_sys=osstat_csv['%user']+osstat_csv['%sys']).head()
# Out:
#                                              FILE DB_NAME       DB_ID  \
# 0  db03bs1-20200217_080033-00036413-00036414.html  DB03BS  2633216536
# 1  db03bs1-20200217_080033-00036413-00036414.html  DB03BS  2633216536
# 2  db03bs1-20200217_090003-00036414-00036415.html  DB03BS  2633216536
# 3  db03bs1-20200217_090003-00036414-00036415.html  DB03BS  2633216536
# 4  db03bs1-20200217_100011-00036415-00036416.html  DB03BS  2633216536
#
#   INSTANCE  INST_NUM     STARTUP_TIME     RELEASE  RAC              HOST_NAME  \
# 0  db03bs1         1  30-Apr-19 07:04  12.1.0.2.0  YES  eoeo03v1.ekiban.local
# 1  db03bs1         1  30-Apr-19 07:04  12.1.0.2.0  YES  eoeo03v1.ekiban.local
# 2  db03bs1         1  30-Apr-19 07:04  12.1.0.2.0  YES  eoeo03v1.ekiban.local
# 3  db03bs1         1  30-Apr-19 07:04  12.1.0.2.0  YES  eoeo03v1.ekiban.local
# 4  db03bs1         1  30-Apr-19 07:04  12.1.0.2.0  YES  eoeo03v1.ekiban.local
#
#            PLATFORM  ...  E_MI  E_S        Snap Time  Load  %busy  %user  \
# ...

# %%
osstat_csv.query('`%user`>0')
# Out:
#                                               FILE DB_NAME       DB_ID  \
# 1   db03bs1-20200217_080033-00036413-00036414.html  DB03BS  2633216536
# 3   db03bs1-20200217_090003-00036414-00036415.html  DB03BS  2633216536
# 5   db03bs1-20200217_100011-00036415-00036416.html  DB03BS  2633216536
# 7   db03bs1-20200217_110018-00036416-00036417.html  DB03BS  2633216536
# 9   db03bs1-20200217_120006-00036417-00036418.html  DB03BS  2633216536
# 11  db03bs1-20200217_130014-00036418-00036419.html  DB03BS  2633216536
# 13  db03bs1-20200217_140022-00036419-00036420.html  DB03BS  2633216536
# 15  db03bs1-20200217_150030-00036420-00036421.html  DB03BS  2633216536
# 17  db03bs1-20200217_160039-00036421-00036422.html  DB03BS  2633216536
# 19  db03bs1-20200217_170004-00036422-00036423.html  DB03BS  2633216536
# 21  db03bs1-20200217_180011-00036423-00036424.html  DB03BS  2633216536
# 23  db03bs1-20200217_190002-00036424-00036425.html  DB03BS  2633216536
# ...

# %%
df
# Out:
#    one  two  three
# a  1.0  1.0    1.0
# b  2.0  2.0    4.0
# c  3.0  3.0    9.0
# d  NaN  4.0    NaN

# %%
df.iloc[1]
# Out:
# one      2.0
# two      2.0
# three    4.0
# Name: b, dtype: float64

# %%
df.describe()
# Out:
#        one       two     three
# count  3.0  4.000000  3.000000
# mean   2.0  2.500000  4.666667
# std    1.0  1.290994  4.041452
# min    1.0  1.000000  1.000000
# 25%    1.5  1.750000  2.500000
# 50%    2.0  2.500000  4.000000
# 75%    2.5  3.250000  6.500000
# max    3.0  4.000000  9.000000
